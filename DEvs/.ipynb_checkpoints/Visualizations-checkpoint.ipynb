# %%
#visualizations

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("../python-ml-course/datasets/customer-churn-model/Customer Churn Model.txt")

# %%
data
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0       KS             128        415  382-4657         no        yes
# 1       OH             107        415  371-7191         no        yes
# 2       NJ             137        415  358-1921         no         no
# 3       OH              84        408  375-9999        yes         no
# 4       OK              75        415  330-6626        yes         no
# ...    ...             ...        ...       ...        ...        ...
# 3328    AZ             192        415  414-4276         no        yes
# 3329    WV              68        415  370-3271         no         no
# 3330    RI              28        510  328-8230         no         no
# 3331    CT             184        510  364-6381        yes         no
# 3332    TN              74        415  400-4344         no        yes
#
#       VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  \
# ...

# %%
data.plot(kind="scatter", x="Day Mins", y="Day Charge")
# Out:
# <AxesSubplot:xlabel='Day Mins', ylabel='Day Charge'>

# %%
figure, axs = plt.subplots(2,2)
data.plot(kind="scatter", x="Day Mins", y="Day Charge", ax=axs[0][0])
data.plot(kind="line", x="Day Mins", y="Day Charge", ax=axs[0][1])
# Out:
# <AxesSubplot:xlabel='Day Mins'>

# %%
k = int(np.ceil(1+np.log2(len(data))))
plt.hist(data["Day Calls"],bins = k)
plt.xlabel("Frecuencia")
plt.title("grafico")
# Out:
# Text(0.5, 1.0, 'grafico')

# %%
subdata1 = data[["Account Length", "Phone", "State"]]

# %%
subdata2 = subdata1[subdata1["State"].str.contains('TN', na=False)]

# %%
subDataDoubleFilter = data[["Phone","State"]][data["State"].str.contains('NY', na=False)]

# %%
subDataDoubleFilter.iloc[:4,:]
# Out:
#         Phone State
# 15   351-7269    NY
# 77   360-1171    NY
# 136  374-8525    NY
# 182  405-2888    NY
